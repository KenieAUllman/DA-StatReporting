# %%
import pandas as pd
import numpy as np
import matplotlib 
import seaborn
import plotly.express as px

# %%
Tik_comments = pd.read_csv("final_data.csv")
# Out:
# C:\Users\luke gevas\AppData\Local\Temp\ipykernel_21648\1428500902.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   Tik_comments = pd.read_csv("final_data.csv")

# %% [markdown]
# I will check the first five rows of data ao i know what I am working with.

# %%
Tik_comments.head(5)
# Out:
#             comment_id                                               text  \
# 0  6816879848683438085  But are you giving him a Tesla? Because he des...
# 1  6816846992812015622              David was just hoping for some help 😢
# 2  6816942564911628294  We ain’t forgot that time he tricked us all in...
# 3  6816824764519301125                                    get him a tesla
# 4  6816821633249001477                                   david ur so hung
#
#               video_id  create_time  like_count  status  author.unique_id  \
# 0  6816821384652557574   1587178528         161       1      lissettecalv
# 1  6816821384652557574   1587170875        1165       1  hellomyfriend0_o
# 2  6816821384652557574   1587193131         249       1     briancarrion_
# 3  6816821384652557574   1587165700        4038       1      slumpgodkayy
# 4  6816821384652557574   1587164971         100       1             _4den
#
#                author.nickname  author.is_private author.language  \
# ...

# %%
average_like_count = Tik_comments["like_count"].mean()
average_like_count
# Out:
# 74.97258797165526

# %% [markdown]
# The information above gives me the average number of likes each person has on their own TikTok account. 75 tells me that a few of his commentors might be influencers, but most are probably people who don't regularly create their own content on TikTok

# %%
Tik_comments.isnull().sum()
# Out:
# comment_id                           0
# text                                 0
# video_id                             0
# create_time                          0
# like_count                           0
# status                               0
# author.unique_id                     0
# author.nickname                      0
# author.is_private                    0
# author.language                      0
# author.signature                 38878
# author.custom_verify            164364
# author.uid                           0
# author.sec_uid                       0
# author.avatar_thumb                  0
# author.region                      135
# author.ins_id                   115000
# author.youtube_channel_title    145634
# author.youtube_channel_id       145634
# author.twitter_id               165012
# dtype: int64

# %% [markdown]
# Now I know which columns in my data are actually missing information. And I can begin to clean it. I don't want to drop anything as I think it would be interesting to examine all these columns further

# %%
Tik_comments["author.youtube_channel_title"].fillna("No Channel", inplace = True) 
Tik_comments["author.signature"].fillna("False", inplace=True)
Tik_comments["author.custom_verify"].fillna("False", inplace=True)
Tik_comments["author.region"].fillna("False", inplace=True)
Tik_comments["author.ins_id"].fillna("False", inplace=True)
Tik_comments["author.youtube_channel_id"].fillna("False", inplace=True)
Tik_comments["author.twitter_id"].fillna("False", inplace=True)

# %%
Tik_comments.isnull().sum()
# Out:
# comment_id                      0
# text                            0
# video_id                        0
# create_time                     0
# like_count                      0
# status                          0
# author.unique_id                0
# author.nickname                 0
# author.is_private               0
# author.language                 0
# author.signature                0
# author.custom_verify            0
# author.uid                      0
# author.sec_uid                  0
# author.avatar_thumb             0
# author.region                   0
# author.ins_id                   0
# author.youtube_channel_title    0
# author.youtube_channel_id       0
# author.twitter_id               0
# dtype: int64

# %%
Tik_comments.video_id
# Out:
# 0         6816821384652557574
# 1         6816821384652557574
# 2         6816821384652557574
# 3         6816821384652557574
# 4         6816821384652557574
#                  ...
# 165105    6831297085137095942
# 165106    6831297085137095942
# 165107    6831297085137095942
# 165108    6831297085137095942
# 165109    6831297085137095942
# Name: video_id, Length: 165110, dtype: int64

# %% [markdown]
# I haven't decided what I want to do with this data.
# 1. The amount of people that like his videos that all have their own youtube channel
# 2. The amount of people who are private vs. public
# 3. The region of the world his views come from

# %%
youtubers = Tik_comments.loc[Tik_comments["author.youtube_channel_title"] != "No Channel"]
youtubers
# Out:
#                  comment_id  \
# 4       6816821633249001477
# 13      6816874886972571654
# 23      6816839795353026565
# 24      6816942164397260805
# 30      6816860870749339654
# ...                     ...
# 165081  6831301420651331589
# 165086  6831298433941716998
# 165095  6831297606040584197
# 165104  6831297442744074245
# 165106  6831297361822711814
#
#                                                      text  \
# 4                                        david ur so hung
# 13                                        Best thing ever
# 23      This two hours that I spend doing a david vide...
# 24                           LMFAOOOO IM LAUGHING SO HARD
# 30      If u see a cute lil silver Acura driving aroun...
# ...                                                   ...
# 165081                                                wow
# 165086                            Seems like a fair trade
# 165095                                     Does he reply?
# ...

# %%
youtubers.nunique()
# Out:
# comment_id                       849
# text                             831
# video_id                           5
# create_time                      843
# like_count                       363
# status                             1
# author.unique_id                 806
# author.nickname                  803
# author.is_private                  2
# author.language                   10
# author.signature                 776
# author.custom_verify               4
# author.uid                       806
# author.sec_uid                   806
# author.avatar_thumb             1612
# author.region                     43
# author.ins_id                    567
# author.youtube_channel_title     804
# author.youtube_channel_id        805
# author.twitter_id                  5
# dtype: int64

# %%
youtubers_unique = Tik_comments.drop_duplicates(subset=["author.youtube_channel_title"], keep="first")
youtubers_unique
# Out:
#                  comment_id  \
# 0       6816879848683438085
# 4       6816821633249001477
# 13      6816874886972571654
# 23      6816839795353026565
# 24      6816942164397260805
# ...                     ...
# 144436  6831297785820659717
# 144444  6831436466107858949
# 144493  6831371342508687366
# 144494  6831367984108781574
# 144498  6831355292098363398
#
#                                                      text  \
# 0       But are you giving him a Tesla? Because he des...
# 4                                        david ur so hung
# 13                                        Best thing ever
# 23      This two hours that I spend doing a david vide...
# 24                           LMFAOOOO IM LAUGHING SO HARD
# ...                                                   ...
# 144436  david do you know what happend with @brycehall...
# 144444          I'm framing that dollar, you tripping lol
# 144493                                         @sky_clown
# ...

# %% [markdown]
# 805 different youtubers have left comments on David's tiktok!

# %%
fig1 = px.histogram(Tik_comments, x="author.region")
fig1.show()
# Out:
# <div>                            <div id="871419ec-0423-4f33-bff4-d833f61e1c43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("871419ec-0423-4f33-bff4-d833f61e1c43")) {                    Plotly.newPlot(                        "871419ec-0423-4f33-bff4-d833f61e1c43",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"author.region=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["US","MT","US","US","US","CA","US","US","US","US","US","IL","US","US","US","BE","US","US","US","US","US","AU","US","US","US","US","US","US","US","US","US","US","CA","US","US","US","US","US","US","GB","US","US","US","US","US
# ...
